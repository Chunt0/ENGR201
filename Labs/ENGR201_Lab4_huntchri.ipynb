# %% [markdown]
# # ENGR 201 Lab 4: Node Voltage Analysis

# %% [markdown]
# ## Abstract
# -----------------------
# In this lab we investigate are to build two different circuits and to analyze them. First we will physically observe the circuits using a digital multimeter, then analytically, using node analysis. One circuit will be made entirely of resistors and another utilizing a diode as a fixed voltage source, this being done to simulate a "supernode".

# %% [markdown]
# ## Equipment
# ------------------------
#
# - Extech EX330
# - GWINSTEK GPE-3323    Serial: GER901898
# - LED
# - 470, 680, 100 and 2 x 3,000 Ω Resistor
# - Acer Nitro 5 - OS: Ubuntu 22.04.1 LTS
# - LTspice - Version: 17.0.35.0

# %% [markdown]
# ## Procedure
# -------------------
#
# 1. Measure the values of the resistors.
#
# 2. Connect the circuit as shown below.
#
# ![image-2.png](attachment:image-2.png)
#
# 3. Measure and record the node-voltages $V_a$ and $V_b$.
#
# 4. Repeat steps 2 and 3 for the circuit shown below.
#
# ![image-3.png](attachment:image-3.png)
#
# 5. Calculate $V_d$, as $V_d=V_a-V_b$
#
# 6. Use node-voltage analysis to solve the first circuit schematic for voltages $V_a$ and $V_b$. Use the measured part values to do the calculations.
#
# 7. Calculate the percent difference between the measured and the calculated values of $V_a$
# and $V_b$.
#
# 8. Repeat steps 6 and 7 for the second circuit. Treat the diode as an ideal diode.
#
# 9. Simulate the second circuit using LTSpice, use a voltage source in place of the LED and set its value to $V_d$.

# %% [markdown]
# ## Measurements
# -------------
#
# Measured Values of Resistors:
#
# \begin{center}
# \begin{tabular}{|c|c|c|}
# \hline
# Resistor & Nominal & Actual \\
# \hline
# R1 & 1000 Ω & 990 Ω \\
# \hline
# R2 & 3000 Ω & 2972 Ω \\
# \hline
# R3 & 3000 Ω & 2958 Ω \\
# \hline
# R4 & 680 Ω & 672 Ω \\
# \hline
# R5 & 470 Ω & 463 Ω \\
# \hline
# \end{tabular}
# \end{center}
#
# Measured Values of Voltages:
#
# \begin{center}
# \begin{tabular}{|c|c|c|}
# \hline
# Circuit & Node a; $V_am$ & Node b; $V_bm$ \\
# \hline
# Circuit 1 & 4.51 V & -4.49 V \\
# \hline
# Circuit 2 & -2.247 V & -0.43 V \\
# \hline
# \end{tabular}
# \end{center}

# %% [markdown]
# ## Analysis
# ------------------

# %% [markdown]
# ## Conclusion
# --------------
# In this lab we analyzed a circuit by three different means - physical measurement, analytical calculation, and simulated calculation. We found that the percentage differences between the measured voltages and the analytically calculated voltages ranged between 0.262% to 2.53%.
