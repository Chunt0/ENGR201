# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

# %% [markdown]
# # ENGR 201 Lab 2: LTSpice

# %% [markdown]
# ## Abstract
# -------------------
# In this weeks lab we are tasked to analyze a circuit which has one unknown resistor value. We must utilize both theoretical calculations as well as modeling software, LTspice, to find values for $V_x$, $I_s$, $I_1$, and $I_2$ with respect to our unknown resistance, $R_3$. We will compare our results from both methods of analysis

# %% [markdown]
# ## Equipment
#
# ----------------------
# - Acer Nitro 5 - OS: Ubuntu 22.04.1 LTS
# - LTspice - Version: 17.0.35.0

# %% [markdown]
# ## Procedure
# -------------------
# ![image-2.png](attachment:image-2.png)
#
# 1. Theoretically derive the equation of the voltage, Vx, as a function of the resistance, R3,
# using Ohm's Law and Kirchhoff's Laws for the circuit shown in Fig. 2.1.
#
# 2. Start the LTspice program. Using the menu bar, click on [File] and select New Schematic
#
# 3. Using the LTspice program construct a circuit file of the circuit shown in Figure 2.1. Save
# the file.
#
# a. Left click on the resistor symbol and drag it to the same location as shown in the
# schematic above. Repeat this process with the other two resistors.
#
# b. Left click the gate symbol to bring up the component library box. Select or type in
# “voltage” and drag it to the appropriate location.
#
# c. Left click on the ground symbol and drag it to the bottom of the schematic.
#
# d. Left click on the pencil in the main menu to connect the components.
#
# e. Click on Simulate in the main menu bar and then select Edit_Simulation_Cmd.
# Click on OK button. The “.op” runtime command will appear at the cursor and can be
# placed anywhere on the schematic.
#
# f. Click on “the running guy” symbol in the button bar.
#
# 4. The resistor, R3, will have an initial fixed value of 1_kΩ.
#
# 5. Run the DC simulation. Your data should match the 1_kΩ data line in Table 2.1.
#
# 6. Make a printer copy of the circuit file and output file (or capture the screen and paste into your report document).
#
# 7. Rerun the DC simulation with 15 values of R3 selected from a range of 1_kΩ to 50_kΩ.
# Collect the required data as shown in Table 2.1.
#
# 8. Make a graph of Vs, Vx and Vy-vs-R3 and IS, I1, and I2-vs-R3 comparing theoretical and
# simulated data. The necessary data for this is provided in the steps above.
#
# 9. Discuss and summarize the results found in steps 1 and 7.
#
# 10.Write your conclusion based on the information found in steps 1 and 7.

# %% [markdown]
# ## Data
# -------------

# %%
path = "./lab2.csv"

lab_data = pd.read_csv(path)

lab_data
# Out:
#     R3 (Ω)  V(vs) (V)  V(vx) (V)  V(vy) (V)  I(R1) (A)  I(R2) (A)  I(R3) (A)  \
# 0     1000         15   8.486842   6.513158   0.008487   0.001974   0.006513
# 1     3000         15   5.833333   9.166667   0.005833   0.002778   0.003056
# 2     5000         15   5.020162   9.979838   0.005020   0.003024   0.001996
# 3     7000         15   4.625750  10.374250   0.004626   0.003144   0.001482
# 4     9000         15   4.392860  10.607140   0.004393   0.003214   0.001179
# 5    11000         15   4.239130  10.760870   0.004239   0.003261   0.000978
# 6    13000         15   4.130070  10.869930   0.004130   0.003294   0.000836
# 7    15000         15   4.048670  10.951330   0.004049   0.003319   0.000730
# 8    17000         15   3.985600  11.014400   0.003986   0.003338   0.000648
# 9    19000         15   3.935290  11.064710   0.003935   0.003353   0.000582
# 10   21000         15   3.894230  11.105770   0.003894   0.003365   0.000529
# ...

# %%
lab_data.plot.scatter(x="R3 (Ω)", y="I(R1) (A)")
plt.title("R3 vs I1")

lab_data.plot.scatter(x="R3 (Ω)", y="I(R2) (A)")
plt.title("R3 vs I2")

lab_data.plot.scatter(x="R3 (Ω)", y="I(R3) (A)")
plt.title("R3 vs I3")

lab_data.plot.scatter(x="R3 (Ω)", y="V(vx) (V)")
plt.title("R3 vs Vx")

lab_data.plot.scatter(x="R3 (Ω)", y="V(vy) (V)")
plt.title("R3 vs Vy")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'R3 (Ω)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# # Calculations
# -------------------------
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Conclusion
# --------------------
